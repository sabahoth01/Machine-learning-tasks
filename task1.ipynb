# %% [markdown]
# ## **Задача 1. Разведочный анализ**
# ### Васаулюа Тази Брюнотт, Гр-М81

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.impute import KNNImputer
import seaborn as sns

# %% [markdown]
# ### 1. Самостоятельно скачать данные (из открытых источников по интересующей тематике, на сайте kaggle, UCI репозитория, Google Dataset Search и др.). Для полного балла нужно выбрать данные, в которых есть пропущенные значения.
#
#  -> [Real Estate Saint Petersburg 2014 - 2019 (Недвижимость Санкт-Петербурга 2014 - 2019)](https://www.kaggle.com/datasets/litvinenko630/real-estate-saint-petersburg-2014-2019) из Kaggle

# %% [markdown]
# ### 2. Считать данные и вывести их основные характеристики, описание признаков.
# #### Описание
# Этот набор данных содержит информацию о предложениях недвижимости, включая различные характеристики объектов недвижимости и прилегающих к ним территорий.
# - airports_nearest: Расстояние до ближайшего аэропорта в метрах
# - balcony: Количество балконов
# - ceiling_height: Высота потолков в метрах
# - Citycenters_narest: Расстояние до центра города в метрах
# - days_exposition: Количество дней, в течение которых объявление было активным (с момента публикации до удаления)
# - first_day_exposition: Дата публикации
# - floor: Количество этажей объекта
# - floors_total: Общее количество этажей, на которых находится объект. этажи в здании
# - is_apartment: Логическое значение, указывающее, является ли объект недвижимости квартирой
# - kitchen_area: Площадь кухни в квадратных метрах
# - last_price: Цена на момент удаления объявления
# - living_area: Жилая площадь в квадратных метрах
# - locality_name: Название населенного пункта
# - open_plan: Логическое значение, указывающее, имеет ли недвижимость открытую планировку
# - parks_around3000: Количество парков в радиусе 3 км
# - parks_nearest: Расстояние до ближайшего парка в метрах
# - ponds_around3000: Количество прудов/водоемов в радиусе 3 км
# - ponds_nearest: Расстояние до ближайшего парка в метрах расстояние до ближайшего пруда/водоема в метрах
# - rooms: Количество комнат
# - studio: Логическое значение, указывающее, является ли объект однокомнатной квартирой
# - total_area: Общая площадь объекта в квадратных метрах
# - total_images: Количество фотографий в списке

# %%
all_data = pd.read_csv("spb\spb_real_estate_data.csv", sep='\t', encoding='utf-8')
all_data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Брюнотт\AppData\Local\Temp\ipykernel_14076\3196156815.py:1: SyntaxWarning: invalid escape sequence '\s'
#   all_data = pd.read_csv("spb\spb_real_estate_data.csv", sep='\t', encoding='utf-8')
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0                2.70          16.0         51.0      8          NaN  ...
# 1                 NaN          11.0         18.6      1          NaN  ...
# 2                 NaN           5.0         34.3      4          NaN  ...
# 3                 NaN          14.0          NaN      9          NaN  ...
# 4                3.03          14.0         32.0     13          NaN  ...
# ...               ...           ...          ...    ...          ...  ...
# 23694            3.70           5.0         73.3      3          NaN  ...
# 23695             NaN           5.0         38.0      4          NaN  ...
# 23696             NaN           3.0         29.7      1          NaN  ...
# 23697            3.00          17.0          NaN     12          NaN  ...
# 23698            2.50           5.0         12.3      1          NaN  ...
#
#        kitchen_area  balcony        locality_name  airports_nearest  \
# 0             25.00      NaN      Санкт-Петербург           18863.0
# 1             11.00      2.0       посёлок Шушары           12817.0
# 2              8.30      0.0      Санкт-Петербург           21741.0
# 3               NaN      0.0      Санкт-Петербург           28098.0
# 4             41.00      NaN      Санкт-Петербург           31856.0
# ...             ...      ...                  ...               ...
# 23694         13.83      NaN      Санкт-Петербург           24665.0
# 23695          8.50      NaN                Тосно               NaN
# 23696           NaN      NaN     село Рождествено               NaN
# 23697         23.30      2.0      Санкт-Петербург           39140.0
# 23698          9.00      NaN  поселок Новый Учхоз               NaN
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0                 16028.0               1.0          482.0               2.0
# 1                 18603.0               0.0            NaN               0.0
# 2                 13933.0               1.0           90.0               2.0
# 3                  6800.0               2.0           84.0               3.0
# 4                  8098.0               2.0          112.0               1.0
# ...                   ...               ...            ...               ...
# 23694              4232.0               1.0          796.0               3.0
# 23695                 NaN               NaN            NaN               NaN
# 23696                 NaN               NaN            NaN               NaN
# 23697             10364.0               2.0          173.0               3.0
# 23698                 NaN               NaN            NaN               NaN
#
#        ponds_nearest  days_exposition
# 0              755.0              NaN
# 1                NaN             81.0
# 2              574.0            558.0
# 3              234.0            424.0
# 4               48.0            121.0
# ...              ...              ...
# 23694          381.0              NaN
# 23695            NaN             45.0
# 23696            NaN              NaN
# 23697          196.0            602.0
# 23698            NaN              NaN
#
# [23699 rows x 22 columns]

# %%
print("Основные характеристики")
print("-----------------------")
print("\n\t** Все пропущенные значения по столбцам:\n\n",all_data.isnull().sum())
print("\n\t** Shape(количество строк и столбцов):", all_data.shape)
print("\n\t** Data types:\n\n", all_data.dtypes)
# Out:
# Основные характеристики
# -----------------------
#
# 	** Все пропущенные значения по столбцам:
#
#  total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64
#
# 	** Shape(количество строк и столбцов): (23699, 22)
#
# 	** Data types:
#
#  total_images              int64
# last_price              float64
# total_area              float64
# first_day_exposition     object
# rooms                     int64
# ceiling_height          float64
# floors_total            float64
# living_area             float64
# floor                     int64
# is_apartment             object
# studio                     bool
# open_plan                  bool
# kitchen_area            float64
# balcony                 float64
# locality_name            object
# airports_nearest        float64
# cityCenters_nearest     float64
# parks_around3000        float64
# parks_nearest           float64
# ponds_around3000        float64
# ponds_nearest           float64
# days_exposition         float64
# dtype: object

# %% [markdown]
# ### Сводная статистика:
# - count : количество наблюдений, отличных от NA/null.
# - unique : уникальные значения
# - max : Максимальное из значений в объекте.
# - min : Минимальное из значений в объекте.
# - mean : Среднее из значений.
# - std : Стандартное отклонение результатов наблюдений.
# - 25%, 50%, 75% : нижний, 50-й и верхний процентили. По умолчанию нижний процентиль равен 25, а верхний - 75.
# - top : это наиболее распространенное значение.
# - freq : - это частота наиболее распространенного значения.

# %%
all_data.describe(include='all')
# Out:
#         total_images    last_price    total_area first_day_exposition  \
# count   23699.000000  2.369900e+04  23699.000000                23699
# unique           NaN           NaN           NaN                 1491
# top              NaN           NaN           NaN  2018-02-01T00:00:00
# freq             NaN           NaN           NaN                  368
# mean        9.858475  6.541549e+06     60.348651                  NaN
# std         5.682529  1.088701e+07     35.654083                  NaN
# min         0.000000  1.219000e+04     12.000000                  NaN
# 25%         6.000000  3.400000e+06     40.000000                  NaN
# 50%         9.000000  4.650000e+06     52.000000                  NaN
# 75%        14.000000  6.800000e+06     69.900000                  NaN
# max        50.000000  7.630000e+08    900.000000                  NaN
#
#                rooms  ceiling_height  floors_total   living_area  \
# count   23699.000000    14504.000000  23613.000000  21796.000000
# unique           NaN             NaN           NaN           NaN
# top              NaN             NaN           NaN           NaN
# freq             NaN             NaN           NaN           NaN
# mean        2.070636        2.771499     10.673824     34.457852
# std         1.078405        1.261056      6.597173     22.030445
# min         0.000000        1.000000      1.000000      2.000000
# 25%         1.000000        2.520000      5.000000     18.600000
# 50%         2.000000        2.650000      9.000000     30.000000
# 75%         3.000000        2.800000     16.000000     42.300000
# max        19.000000      100.000000     60.000000    409.700000
#
#                floor is_apartment  ...  kitchen_area       balcony  \
# count   23699.000000         2775  ...  21421.000000  12180.000000
# unique           NaN            2  ...           NaN           NaN
# top              NaN        False  ...           NaN           NaN
# freq             NaN         2725  ...           NaN           NaN
# mean        5.892358          NaN  ...     10.569807      1.150082
# std         4.885249          NaN  ...      5.905438      1.071300
# min         1.000000          NaN  ...      1.300000      0.000000
# 25%         2.000000          NaN  ...      7.000000      0.000000
# 50%         4.000000          NaN  ...      9.100000      1.000000
# 75%         8.000000          NaN  ...     12.000000      2.000000
# max        33.000000          NaN  ...    112.000000      5.000000
#
#           locality_name  airports_nearest cityCenters_nearest  \
# count             23650      18157.000000        18180.000000
# unique              364               NaN                 NaN
# top     Санкт-Петербург               NaN                 NaN
# freq              15721               NaN                 NaN
# mean                NaN      28793.672193        14191.277833
# std                 NaN      12630.880622         8608.386210
# min                 NaN          0.000000          181.000000
# 25%                 NaN      18585.000000         9238.000000
# 50%                 NaN      26726.000000        13098.500000
# 75%                 NaN      37273.000000        16293.000000
# max                 NaN      84869.000000        65968.000000
#
#         parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# count       18181.000000    8079.000000      18181.000000    9110.000000
# unique               NaN            NaN               NaN            NaN
# top                  NaN            NaN               NaN            NaN
# freq                 NaN            NaN               NaN            NaN
# mean            0.611408     490.804555          0.770255     517.980900
# std             0.802074     342.317995          0.938346     277.720643
# min             0.000000       1.000000          0.000000      13.000000
# 25%             0.000000     288.000000          0.000000     294.000000
# 50%             0.000000     455.000000          1.000000     502.000000
# 75%             1.000000     612.000000          1.000000     729.000000
# max             3.000000    3190.000000          3.000000    1344.000000
#
#         days_exposition
# count      20518.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean         180.888634
# std          219.727988
# min            1.000000
# 25%           45.000000
# 50%           95.000000
# 75%          232.000000
# max         1580.000000
#
# [11 rows x 22 columns]

# %% [markdown]
# ### 3. Сформулировать задачу предсказания, какой признак интересно было бы предсказывать по остальным.
#
#     -> Выбрала предсказывать цену объекта с учетом количества комнат, расстояния до центра города, количества этажей, жилой площади, расстояния до ближайшего парка и общей площади.
#
#     признак "last_price"

# %% [markdown]
# ### 4. Провести анализ признаков, используя визуализацию (hist(), boxplot(), countplot(), barplot() и тд), сделать выводы, которые могут быть полезны при дальнейшем решении задачи предсказания.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=all_data, x='total_area', bins=30, kde=True)
plt.title('Распределение площади')
plt.show()

# %%
sns.scatterplot(x='airports_nearest', y='last_price', data=all_data)
plt.title('Связь между расстоянием до аэропорта и последней ценой')
plt.xlabel('Расстояние до аэропорта')
plt.ylabel('Последняя цена')
plt.show()

# %%
sns.scatterplot(x='cityCenters_nearest', y='last_price', data=all_data)
plt.title('Связь между Расстоянием до центра города и последней ценой')
plt.xlabel('Расстояние до центра города')
plt.ylabel('Последняя цена')
plt.show()

# %%
_, ax = plt.subplots(1, 2, figsize=(15, 6))
all_data[all_data['total_area'] <= 100]['total_area'].plot.hist(ax=ax[0], edgecolor='black', bins=30)
ax[0].set_title('Распределение площади')
x1 = list(range(0, 100, 10))
ax[0].set_xticks(x1)
all_data[all_data['total_area'] >= 100]['total_area'].plot.hist(ax=ax[1], edgecolor='black', bins=30)
ax[1].set_title('Распределение площади')
x1 = list(range(100, 550, 50))
ax[1].set_xticks(x1)
# Out:
# [<matplotlib.axis.XTick at 0x2bbf82a8110>,
#  <matplotlib.axis.XTick at 0x2bbf82a80e0>,
#  <matplotlib.axis.XTick at 0x2bbf81c8530>,
#  <matplotlib.axis.XTick at 0x2bbf81858b0>,
#  <matplotlib.axis.XTick at 0x2bbf8184d40>,
#  <matplotlib.axis.XTick at 0x2bbf81870b0>,
#  <matplotlib.axis.XTick at 0x2bbf8187e00>,
#  <matplotlib.axis.XTick at 0x2bbf8114320>,
#  <matplotlib.axis.XTick at 0x2bbf80f7440>]

# %%
_, ax = plt.subplots(1, 2, figsize=(15, 6))
all_data[all_data['last_price'] <= 5+1e7]['last_price'].plot.hist(ax=ax[0], edgecolor='black', bins=30)
ax[0].set_title('Распределение цены')

all_data[all_data['last_price'] >= 1+1e8]['last_price'].plot.hist(ax=ax[1],  edgecolor='black', bins=30)
ax[1].set_title('Распределение цен ')
# Out:
# Text(0.5, 1.0, 'Распределение цен ')

# %% [markdown]
# ### Вывод по задаче 4
# * Общая площадь большинства объектов варьируется от 40 до 60 квадратных метров.
# * Чем ближе объект к аэропорту, тем дороже он стоит.
# * Чем ближе объект к центру города, тем дороже он стоит.

# %% [markdown]
# ### 5. Произвести чистку данных (Data Cleaning). Например, заполнить пропущенные значения чем то осмысленным для поставленной задачи.

# %%
all_data.info()
print("\n\t** Все пропущенные значения по столбцам:\n\n",all_data.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
#  15  airports_nearest      18157 non-null  float64
#  16  cityCenters_nearest   18180 non-null  float64
#  17  parks_around3000      18181 non-null  float64
#  18  parks_nearest         8079 non-null   float64
#  19  ponds_around3000      18181 non-null  float64
#  20  ponds_nearest         9110 non-null   float64
#  21  days_exposition       20518 non-null  float64
# dtypes: bool(2), float64(14), int64(3), object(3)
# memory usage: 3.7+ MB
#
# 	** Все пропущенные значения по столбцам:
#
#  total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Поскольку мой набор данных заполнен данными нескольких типов, я буду использовать разные подходы:
#  * для работы со столбцом "is_apartment" я решила использовать алгоритм KNN для работы с отсутствующими данными. Основываясь на данных из столбцов 'last_price', 'total_area', 'rooms', 'studio', 'open_plan','floors_total', я попытаюсь написать простую модель прогнозирования для прогнозирования пропущенных значений.
#  * Для столбца "locality_name " я заполню пропущенные значения "Неизвестно"
#  * Поскольку остальные столбцы являются числовыми значениями, я заполню их, используя среднее значение каждого из значений.

# %%
# Prepare the data
all_data['is_apartment'] = all_data['is_apartment'].astype(bool)

# Create a KNN imputer
imputer = KNNImputer(n_neighbors=7)

# Fit the imputer
imputer.fit(all_data[['last_price', 'total_area', 'rooms', 'studio', 'open_plan','floors_total']])

# Transform the data
imputed_values = imputer.transform(all_data[['last_price', 'total_area', 'rooms', 'studio', 'open_plan','floors_total']])

# Convert the imputed values to a Boolean array
imputed_values = (imputed_values[:, -1] > 0.5).astype(bool)

# Convert the imputed values to a pandas Series
imputed_values = pd.Series(imputed_values)

# Replace the missing values in the is_apartment column with the imputed values
all_data['is_apartment'] = all_data['is_apartment'].fillna(imputed_values)
print("\n\t** Все пропущенные значения по столбцам:\n\n",all_data.isnull().sum())
all_data
# Out:
# 	** Все пропущенные значения по столбцам:
#
#  total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0                2.70          16.0         51.0      8          True  ...
# 1                 NaN          11.0         18.6      1          True  ...
# 2                 NaN           5.0         34.3      4          True  ...
# 3                 NaN          14.0          NaN      9          True  ...
# 4                3.03          14.0         32.0     13          True  ...
# ...               ...           ...          ...    ...           ...  ...
# 23694            3.70           5.0         73.3      3          True  ...
# 23695             NaN           5.0         38.0      4          True  ...
# 23696             NaN           3.0         29.7      1          True  ...
# 23697            3.00          17.0          NaN     12          True  ...
# 23698            2.50           5.0         12.3      1          True  ...
#
#        kitchen_area  balcony        locality_name  airports_nearest  \
# 0             25.00      NaN      Санкт-Петербург           18863.0
# 1             11.00      2.0       посёлок Шушары           12817.0
# 2              8.30      0.0      Санкт-Петербург           21741.0
# 3               NaN      0.0      Санкт-Петербург           28098.0
# 4             41.00      NaN      Санкт-Петербург           31856.0
# ...             ...      ...                  ...               ...
# 23694         13.83      NaN      Санкт-Петербург           24665.0
# 23695          8.50      NaN                Тосно               NaN
# 23696           NaN      NaN     село Рождествено               NaN
# 23697         23.30      2.0      Санкт-Петербург           39140.0
# 23698          9.00      NaN  поселок Новый Учхоз               NaN
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0                 16028.0               1.0          482.0               2.0
# 1                 18603.0               0.0            NaN               0.0
# 2                 13933.0               1.0           90.0               2.0
# 3                  6800.0               2.0           84.0               3.0
# 4                  8098.0               2.0          112.0               1.0
# ...                   ...               ...            ...               ...
# 23694              4232.0               1.0          796.0               3.0
# 23695                 NaN               NaN            NaN               NaN
# 23696                 NaN               NaN            NaN               NaN
# 23697             10364.0               2.0          173.0               3.0
# 23698                 NaN               NaN            NaN               NaN
#
#        ponds_nearest  days_exposition
# 0              755.0              NaN
# 1                NaN             81.0
# 2              574.0            558.0
# 3              234.0            424.0
# 4               48.0            121.0
# ...              ...              ...
# 23694          381.0              NaN
# 23695            NaN             45.0
# 23696            NaN              NaN
# 23697          196.0            602.0
# 23698            NaN              NaN
#
# [23699 rows x 22 columns]

# %%
all_data[['locality_name']] = all_data[['locality_name']].fillna("Неизвестно")
all_data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0                2.70          16.0         51.0      8          True  ...
# 1                 NaN          11.0         18.6      1          True  ...
# 2                 NaN           5.0         34.3      4          True  ...
# 3                 NaN          14.0          NaN      9          True  ...
# 4                3.03          14.0         32.0     13          True  ...
# ...               ...           ...          ...    ...           ...  ...
# 23694            3.70           5.0         73.3      3          True  ...
# 23695             NaN           5.0         38.0      4          True  ...
# 23696             NaN           3.0         29.7      1          True  ...
# 23697            3.00          17.0          NaN     12          True  ...
# 23698            2.50           5.0         12.3      1          True  ...
#
#        kitchen_area  balcony        locality_name  airports_nearest  \
# 0             25.00      NaN      Санкт-Петербург           18863.0
# 1             11.00      2.0       посёлок Шушары           12817.0
# 2              8.30      0.0      Санкт-Петербург           21741.0
# 3               NaN      0.0      Санкт-Петербург           28098.0
# 4             41.00      NaN      Санкт-Петербург           31856.0
# ...             ...      ...                  ...               ...
# 23694         13.83      NaN      Санкт-Петербург           24665.0
# 23695          8.50      NaN                Тосно               NaN
# 23696           NaN      NaN     село Рождествено               NaN
# 23697         23.30      2.0      Санкт-Петербург           39140.0
# 23698          9.00      NaN  поселок Новый Учхоз               NaN
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0                 16028.0               1.0          482.0               2.0
# 1                 18603.0               0.0            NaN               0.0
# 2                 13933.0               1.0           90.0               2.0
# 3                  6800.0               2.0           84.0               3.0
# 4                  8098.0               2.0          112.0               1.0
# ...                   ...               ...            ...               ...
# 23694              4232.0               1.0          796.0               3.0
# 23695                 NaN               NaN            NaN               NaN
# 23696                 NaN               NaN            NaN               NaN
# 23697             10364.0               2.0          173.0               3.0
# 23698                 NaN               NaN            NaN               NaN
#
#        ponds_nearest  days_exposition
# 0              755.0              NaN
# 1                NaN             81.0
# 2              574.0            558.0
# 3              234.0            424.0
# 4               48.0            121.0
# ...              ...              ...
# 23694          381.0              NaN
# 23695            NaN             45.0
# 23696            NaN              NaN
# 23697          196.0            602.0
# 23698            NaN              NaN
#
# [23699 rows x 22 columns]

# %%
all_data[['days_exposition', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest', 'ceiling_height', 'floors_total', 'living_area', 'kitchen_area', 'balcony', 'airports_nearest', 'cityCenters_nearest']] = all_data[['days_exposition', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest', 'ceiling_height', 'floors_total', 'living_area', 'kitchen_area', 'balcony', 'airports_nearest', 'cityCenters_nearest']].fillna(all_data[['days_exposition', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest', 'ceiling_height', 'floors_total', 'living_area', 'kitchen_area', 'balcony', 'airports_nearest', 'cityCenters_nearest']].mean())
print("\n\t** Все пропущенные значения по столбцам:\n\n",all_data.isnull().sum())
# Out:
# 	** Все пропущенные значения по столбцам:
#
#  total_images            0
# last_price              0
# total_area              0
# first_day_exposition    0
# rooms                   0
# ceiling_height          0
# floors_total            0
# living_area             0
# floor                   0
# is_apartment            0
# studio                  0
# open_plan               0
# kitchen_area            0
# balcony                 0
# locality_name           0
# airports_nearest        0
# cityCenters_nearest     0
# parks_around3000        0
# parks_nearest           0
# ponds_around3000        0
# ponds_nearest           0
# days_exposition         0
# dtype: int64

# %% [markdown]
# ### 6. (+2 балла) Выполнить полезные преобразования данных (например, трансформировать категариальные признаки в количественные если это нужно), убрать ненужные признаки, создать новые (Feature Engineering).
#
#   * В моем наборе данных у меня есть эти таблицы: 'first_day_exposition', 'days_exposition' . Для будущих манипуляций (например, в задаче прогнозирования) они будут мне не так полезны. Было бы здорово, если бы они указывали, например, год постройки здания, это было бы отличной особенностью.
#
#   * Я могу создать новый столбец : цена за площадь(price_per_area), которая является хорошей функцией при работе с данными о недвижимости
#   * Чтобы было проще работать со столбцом "locality_name", я решила преобразовать его в числовые значения (используя метку для каждого значения, а затем распечатать все метки с соответствующими им истинными значениями).

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder
le = LabelEncoder()

# Fit the LabelEncoder to the locality_name column
le.fit(all_data['locality_name'])

# Transform the locality_name column to numerical values
all_data['locality_name'] = le.transform(all_data['locality_name'])

# Print out the legend
print("Legend:")
for i, label in enumerate(le.classes_):
    print(f"{i}: {label}")
# Out:
# Legend:
# 0: Бокситогорск
# 1: Волосово
# 2: Волхов
# 3: Всеволожск
# 4: Выборг
# 5: Высоцк
# 6: Гатчина
# 7: Зеленогорск
# 8: Ивангород
# 9: Каменногорск
# 10: Кингисепп
# 11: Кириши
# 12: Кировск
# 13: Колпино
# 14: Коммунар
# 15: Красное Село
# 16: Кронштадт
# 17: Кудрово
# 18: Лодейное Поле
# 19: Ломоносов
# 20: Луга
# 21: Любань
# 22: Мурино
# 23: Неизвестно
# 24: Никольское
# 25: Новая Ладога
# 26: Отрадное
# 27: Павловск
# 28: Петергоф
# 29: Пикалёво
# 30: Подпорожье
# 31: Приморск
# 32: Приозерск
# 33: Пушкин
# 34: Санкт-Петербург
# 35: Светогорск
# 36: Сертолово
# 37: Сестрорецк
# 38: Сланцы
# 39: Сосновый Бор
# 40: Сясьстрой
# 41: Тихвин
# 42: Тосно
# 43: Шлиссельбург
# 44: городской поселок Большая Ижора
# 45: городской поселок Янино-1
# 46: городской посёлок Будогощь
# 47: городской посёлок Виллози
# 48: городской посёлок Лесогорский
# 49: городской посёлок Мга
# 50: городской посёлок Назия
# 51: городской посёлок Новоселье
# 52: городской посёлок Павлово
# 53: городской посёлок Рощино
# 54: городской посёлок Свирьстрой
# 55: городской посёлок Советский
# 56: городской посёлок Фёдоровское
# 57: городской посёлок Янино-1
# 58: деревня Агалатово
# 59: деревня Аро
# 60: деревня Батово
# 61: деревня Бегуницы
# 62: деревня Белогорка
# 63: деревня Большая Вруда
# 64: деревня Большая Пустомержа
# 65: деревня Большие Колпаны
# 66: деревня Большое Рейзино
# 67: деревня Большой Сабск
# 68: деревня Бор
# 69: деревня Борисова Грива
# 70: деревня Ваганово
# 71: деревня Вартемяги
# 72: деревня Вахнова Кара
# 73: деревня Выскатка
# 74: деревня Гарболово
# 75: деревня Глинка
# 76: деревня Горбунки
# 77: деревня Гостилицы
# 78: деревня Заклинье
# 79: деревня Заневка
# 80: деревня Зимитицы
# 81: деревня Извара
# 82: деревня Иссад
# 83: деревня Калитино
# 84: деревня Кальтино
# 85: деревня Камышовка
# 86: деревня Каськово
# 87: деревня Келози
# 88: деревня Кипень
# 89: деревня Кисельня
# 90: деревня Колтуши
# 91: деревня Коркино
# 92: деревня Котлы
# 93: деревня Кривко
# 94: деревня Кудрово
# 95: деревня Кузьмолово
# 96: деревня Курковицы
# 97: деревня Куровицы
# 98: деревня Куттузи
# 99: деревня Лаврики
# 100: деревня Лаголово
# 101: деревня Лампово
# 102: деревня Лесколово
# 103: деревня Лопухинка
# 104: деревня Лупполово
# 105: деревня Малая Романовка
# 106: деревня Малое Верево
# 107: деревня Малое Карлино
# 108: деревня Малые Колпаны
# 109: деревня Мануйлово
# 110: деревня Меньково
# 111: деревня Мины
# 112: деревня Мистолово
# 113: деревня Ненимяки
# 114: деревня Нижние Осельки
# 115: деревня Нижняя
# 116: деревня Низино
# 117: деревня Новое Девяткино
# 118: деревня Новолисино
# 119: деревня Нурма
# 120: деревня Оржицы
# 121: деревня Парицы
# 122: деревня Пельгора
# 123: деревня Пеники
# 124: деревня Пижма
# 125: деревня Пикколово
# 126: деревня Пудомяги
# 127: деревня Пустынка
# 128: деревня Пчева
# 129: деревня Рабитицы
# 130: деревня Разбегаево
# 131: деревня Раздолье
# 132: деревня Разметелево
# 133: деревня Рапполово
# 134: деревня Реброво
# 135: деревня Русско
# 136: деревня Сижно
# 137: деревня Снегирёвка
# 138: деревня Старая
# 139: деревня Старая Пустошь
# 140: деревня Старое Хинколово
# 141: деревня Старополье
# 142: деревня Старосиверская
# 143: деревня Старые Бегуницы
# 144: деревня Суоранда
# 145: деревня Сяськелево
# 146: деревня Тарасово
# 147: деревня Терпилицы
# 148: деревня Тихковицы
# 149: деревня Тойворово
# 150: деревня Торосово
# 151: деревня Торошковичи
# 152: деревня Трубников Бор
# 153: деревня Фалилеево
# 154: деревня Фёдоровское
# 155: деревня Хапо-Ое
# 156: деревня Хязельки
# 157: деревня Чудской Бор
# 158: деревня Шпаньково
# 159: деревня Щеглово
# 160: деревня Юкки
# 161: деревня Ялгино
# 162: деревня Яльгелево
# 163: деревня Ям-Тесово
# 164: коттеджный поселок Кивеннапа Север
# 165: коттеджный поселок Счастье
# 166: коттеджный посёлок Лесное
# 167: поселок Аннино
# 168: поселок Барышево
# 169: поселок Бугры
# 170: поселок Возрождение
# 171: поселок Войсковицы
# 172: поселок Володарское
# 173: поселок Гаврилово
# 174: поселок Гарболово
# 175: поселок Гладкое
# 176: поселок Глажево
# 177: поселок Глебычево
# 178: поселок Гончарово
# 179: поселок Громово
# 180: поселок Дружноселье
# 181: поселок Елизаветино
# 182: поселок Жилгородок
# 183: поселок Жилпосёлок
# 184: поселок Житково
# 185: поселок Заводской
# 186: поселок Запорожское
# 187: поселок Зимитицы
# 188: поселок Ильичёво
# 189: поселок Калитино
# 190: поселок Каложицы
# 191: поселок Кингисеппский
# 192: поселок Кирпичное
# 193: поселок Кобралово
# 194: поселок Кобринское
# 195: поселок Коммунары
# 196: поселок Коробицыно
# 197: поселок Котельский
# 198: поселок Красная Долина
# 199: поселок Красносельское
# 200: поселок Лесное
# 201: поселок Лисий Нос
# 202: поселок Лукаши
# 203: поселок Любань
# 204: поселок Мельниково
# 205: поселок Мичуринское
# 206: поселок Молодцово
# 207: поселок Мурино
# 208: поселок Новый Свет
# 209: поселок Новый Учхоз
# 210: поселок Оредеж
# 211: поселок Пансионат Зелёный Бор
# 212: поселок Первомайское
# 213: поселок Перово
# 214: поселок Петровское
# 215: поселок Победа
# 216: поселок Поляны
# 217: поселок Почап
# 218: поселок Починок
# 219: поселок Пушное
# 220: поселок Пчевжа
# 221: поселок Рабитицы
# 222: поселок Романовка
# 223: поселок Ромашки
# 224: поселок Рябово
# 225: поселок Севастьяново
# 226: поселок Селезнёво
# 227: поселок Сельцо
# 228: поселок Семиозерье
# 229: поселок Семрино
# 230: поселок Серебрянский
# 231: поселок Совхозный
# 232: поселок Старая Малукса
# 233: поселок Стеклянный
# 234: поселок Сумино
# 235: поселок Суходолье
# 236: поселок Тельмана
# 237: поселок Терволово
# 238: поселок Торковичи
# 239: поселок Тёсово-4
# 240: поселок Углово
# 241: поселок Усть-Луга
# 242: поселок Ушаки
# 243: поселок Цвелодубово
# 244: поселок Цвылёво
# 245: поселок городского типа Большая Ижора
# 246: поселок городского типа Вырица
# 247: поселок городского типа Дружная Горка
# 248: поселок городского типа Дубровка
# 249: поселок городского типа Ефимовский
# 250: поселок городского типа Кондратьево
# 251: поселок городского типа Красный Бор
# 252: поселок городского типа Кузьмоловский
# 253: поселок городского типа Лебяжье
# 254: поселок городского типа Лесогорский
# 255: поселок городского типа Назия
# 256: поселок городского типа Никольский
# 257: поселок городского типа Приладожский
# 258: поселок городского типа Рахья
# 259: поселок городского типа Рощино
# 260: поселок городского типа Рябово
# 261: поселок городского типа Синявино
# 262: поселок городского типа Советский
# 263: поселок городского типа Токсово
# 264: поселок городского типа Форносово
# 265: поселок городского типа имени Свердлова
# 266: поселок станции Вещево
# 267: поселок станции Корнево
# 268: поселок станции Лужайка
# 269: поселок станции Приветнинское
# 270: посёлок Александровская
# 271: посёлок Алексеевка
# 272: посёлок Аннино
# 273: посёлок Белоостров
# 274: посёлок Бугры
# 275: посёлок Возрождение
# 276: посёлок Войскорово
# 277: посёлок Высокоключевой
# 278: посёлок Гаврилово
# 279: посёлок Дзержинского
# 280: посёлок Жилгородок
# 281: посёлок Ильичёво
# 282: посёлок Кикерино
# 283: посёлок Кобралово
# 284: посёлок Коробицыно
# 285: посёлок Левашово
# 286: посёлок Ленинское
# 287: посёлок Лисий Нос
# 288: посёлок Мельниково
# 289: посёлок Металлострой
# 290: посёлок Мичуринское
# 291: посёлок Молодёжное
# 292: посёлок Мурино
# 293: посёлок Мыза-Ивановка
# 294: посёлок Новогорелово
# 295: посёлок Новый Свет
# 296: посёлок Пансионат Зелёный Бор
# 297: посёлок Парголово
# 298: посёлок Перово
# 299: посёлок Песочный
# 300: посёлок Петро-Славянка
# 301: посёлок Петровское
# 302: посёлок Платформа 69-й километр
# 303: посёлок Плодовое
# 304: посёлок Плоское
# 305: посёлок Победа
# 306: посёлок Поляны
# 307: посёлок Понтонный
# 308: посёлок Пригородный
# 309: посёлок Пудость
# 310: посёлок Репино
# 311: посёлок Ропша
# 312: посёлок Сапёрное
# 313: посёлок Сапёрный
# 314: посёлок Сосново
# 315: посёлок Старая Малукса
# 316: посёлок Стеклянный
# 317: посёлок Стрельна
# 318: посёлок Суйда
# 319: посёлок Сумино
# 320: посёлок Тельмана
# 321: посёлок Терволово
# 322: посёлок Торфяное
# 323: посёлок Усть-Ижора
# 324: посёлок Усть-Луга
# 325: посёлок Форт Красная Горка
# 326: посёлок Шугозеро
# 327: посёлок Шушары
# 328: посёлок Щеглово
# 329: посёлок городского типа Важины
# 330: посёлок городского типа Вознесенье
# 331: посёлок городского типа Вырица
# 332: посёлок городского типа Красный Бор
# 333: посёлок городского типа Кузнечное
# 334: посёлок городского типа Кузьмоловский
# 335: посёлок городского типа Лебяжье
# 336: посёлок городского типа Мга
# 337: посёлок городского типа Павлово
# 338: посёлок городского типа Рощино
# 339: посёлок городского типа Рябово
# 340: посёлок городского типа Сиверский
# 341: посёлок городского типа Тайцы
# 342: посёлок городского типа Токсово
# 343: посёлок городского типа Ульяновка
# 344: посёлок городского типа Форносово
# 345: посёлок городского типа имени Морозова
# 346: посёлок городского типа имени Свердлова
# 347: посёлок при железнодорожной станции Вещево
# 348: посёлок при железнодорожной станции Приветнинское
# 349: посёлок станции Громово
# 350: посёлок станции Свирь
# 351: садоводческое некоммерческое товарищество Лесная Поляна
# 352: садовое товарищество Новая Ропша
# 353: садовое товарищество Приладожский
# 354: садовое товарищество Рахья
# 355: садовое товарищество Садко
# 356: село Копорье
# 357: село Никольское
# 358: село Павлово
# 359: село Паша
# 360: село Путилово
# 361: село Рождествено
# 362: село Русско-Высоцкое
# 363: село Старая Ладога
# 364: село Шум

# %%
# Creating a new feature: price_per_area
all_data['price_per_area'] = all_data['last_price'] / all_data['total_area']
all_data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.700000          16.0    51.000000      8          True  ...
# 1            2.771499          11.0    18.600000      1          True  ...
# 2            2.771499           5.0    34.300000      4          True  ...
# 3            2.771499          14.0    34.457852      9          True  ...
# 4            3.030000          14.0    32.000000     13          True  ...
# ...               ...           ...          ...    ...           ...  ...
# 23694        3.700000           5.0    73.300000      3          True  ...
# 23695        2.771499           5.0    38.000000      4          True  ...
# 23696        2.771499           3.0    29.700000      1          True  ...
# 23697        3.000000          17.0    34.457852     12          True  ...
# 23698        2.500000           5.0    12.300000      1          True  ...
#
#         balcony  locality_name  airports_nearest  cityCenters_nearest  \
# 0      1.150082             34      18863.000000         16028.000000
# 1      2.000000            327      12817.000000         18603.000000
# 2      0.000000             34      21741.000000         13933.000000
# 3      0.000000             34      28098.000000          6800.000000
# 4      1.150082             34      31856.000000          8098.000000
# ...         ...            ...               ...                  ...
# 23694  1.150082             34      24665.000000          4232.000000
# 23695  1.150082             42      28793.672193         14191.277833
# 23696  1.150082            361      28793.672193         14191.277833
# 23697  2.000000             34      39140.000000         10364.000000
# 23698  1.150082            209      28793.672193         14191.277833
#
#        parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 0              1.000000     482.000000          2.000000       755.0000
# 1              0.000000     490.804555          0.000000       517.9809
# 2              1.000000      90.000000          2.000000       574.0000
# 3              2.000000      84.000000          3.000000       234.0000
# 4              2.000000     112.000000          1.000000        48.0000
# ...                 ...            ...               ...            ...
# 23694          1.000000     796.000000          3.000000       381.0000
# 23695          0.611408     490.804555          0.770255       517.9809
# 23696          0.611408     490.804555          0.770255       517.9809
# 23697          2.000000     173.000000          3.000000       196.0000
# 23698          0.611408     490.804555          0.770255       517.9809
#
#        days_exposition  price_per_area
# 0           180.888634   120370.370370
# 1            81.000000    82920.792079
# 2           558.000000    92785.714286
# 3           424.000000   408176.100629
# 4           121.000000   100000.000000
# ...                ...             ...
# 23694       180.888634    72490.845228
# 23695        45.000000    52542.372881
# 23696       180.888634    44091.710758
# 23697       602.000000   149511.400651
# 23698       180.888634    41795.665635
#
# [23699 rows x 23 columns]

# %%
data_drop_colums = all_data.drop(columns=['first_day_exposition', 'days_exposition', 'total_images'])
data_drop_colums
# Out:
#        last_price  total_area  rooms  ceiling_height  floors_total  \
# 0      13000000.0      108.00      3        2.700000          16.0
# 1       3350000.0       40.40      1        2.771499          11.0
# 2       5196000.0       56.00      2        2.771499           5.0
# 3      64900000.0      159.00      3        2.771499          14.0
# 4      10000000.0      100.00      2        3.030000          14.0
# ...           ...         ...    ...             ...           ...
# 23694   9700000.0      133.81      3        3.700000           5.0
# 23695   3100000.0       59.00      3        2.771499           5.0
# 23696   2500000.0       56.70      2        2.771499           3.0
# 23697  11475000.0       76.75      2        3.000000          17.0
# 23698   1350000.0       32.30      1        2.500000           5.0
#
#        living_area  floor  is_apartment  studio  open_plan  kitchen_area  \
# 0        51.000000      8          True   False      False     25.000000
# 1        18.600000      1          True   False      False     11.000000
# 2        34.300000      4          True   False      False      8.300000
# 3        34.457852      9          True   False      False     10.569807
# 4        32.000000     13          True   False      False     41.000000
# ...            ...    ...           ...     ...        ...           ...
# 23694    73.300000      3          True   False      False     13.830000
# 23695    38.000000      4          True   False      False      8.500000
# 23696    29.700000      1          True   False      False     10.569807
# 23697    34.457852     12          True   False      False     23.300000
# 23698    12.300000      1          True   False      False      9.000000
#
#         balcony  locality_name  airports_nearest  cityCenters_nearest  \
# 0      1.150082             34      18863.000000         16028.000000
# 1      2.000000            327      12817.000000         18603.000000
# 2      0.000000             34      21741.000000         13933.000000
# 3      0.000000             34      28098.000000          6800.000000
# 4      1.150082             34      31856.000000          8098.000000
# ...         ...            ...               ...                  ...
# 23694  1.150082             34      24665.000000          4232.000000
# 23695  1.150082             42      28793.672193         14191.277833
# 23696  1.150082            361      28793.672193         14191.277833
# 23697  2.000000             34      39140.000000         10364.000000
# 23698  1.150082            209      28793.672193         14191.277833
#
#        parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 0              1.000000     482.000000          2.000000       755.0000
# 1              0.000000     490.804555          0.000000       517.9809
# 2              1.000000      90.000000          2.000000       574.0000
# 3              2.000000      84.000000          3.000000       234.0000
# 4              2.000000     112.000000          1.000000        48.0000
# ...                 ...            ...               ...            ...
# 23694          1.000000     796.000000          3.000000       381.0000
# 23695          0.611408     490.804555          0.770255       517.9809
# 23696          0.611408     490.804555          0.770255       517.9809
# 23697          2.000000     173.000000          3.000000       196.0000
# 23698          0.611408     490.804555          0.770255       517.9809
#
#        price_per_area
# 0       120370.370370
# 1        82920.792079
# 2        92785.714286
# 3       408176.100629
# 4       100000.000000
# ...               ...
# 23694    72490.845228
# 23695    52542.372881
# 23696    44091.710758
# 23697   149511.400651
# 23698    41795.665635
#
# [23699 rows x 20 columns]

# %% [markdown]
#  ### 7. (+1 балл) Оценить зависимость между признаками (визуализация или построение матрицы корреляции).

# %%
# Calculate the correlation matrix
corr_matrix = data_drop_colums.corr()

# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(30, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### Вывод
# Коэффициент, близкий к:
# 1, указывает на сильную положительную корреляцию (например, при увеличении одной переменной другая имеет тенденцию к увеличению).
# -1 указывает на сильную отрицательную корреляцию (например, при увеличении одной переменной другая имеет тенденцию к уменьшению).
# 0 указывает на отсутствие корреляции (например, переменные не связаны между собой).
#
# -> В моем случае, например, total_area и rooms имеют сильную корреляцию. по мере увеличения количества комнат общая площадь также имеет тенденцию к увеличению.
#
# -> Но cityCenter_nearest и is_apartment слабо коррелируют. они независимы. когда объект находится недалеко от города, это необязательно означает, что этот объект является квартирой.
